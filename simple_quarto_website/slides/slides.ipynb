# %% [raw]
# ---
# title: "DSAN5000-Lab1.2"
# author: "Mingxun Chen"
# bibliography: ../../reference.bib
# format: revealjs
# ---

# %% [markdown]
# ## Section 1
# citation:
# [@zhou2021informer]
#
# ## Section 2
# embedded images:
#
# ::: {layout-ncol=2}
# ![](images/puff.png){width=300}
#
# ![](images/luna.png){width=300}
# :::

# %% [markdown]
# ## Section 3

# %%
#| echo: true
#| code-fold: true

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 3)

fig, axs = plt.subplots(2)
axs[0].plot(x, y)
axs[1].plot(x, -y)

plt.show()

# %% [markdown]
# ## References:
